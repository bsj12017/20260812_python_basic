# %%
print("백승준")
number = 34
print(number)
print("숫자는:", number)
# Out:
# 백승준
# 34
# 숫자는: 34

# %%
name = "백승준"
age = 34
print(f"이름: {name}, 나이: {age}")
# Out:
# 이름: 백승준, 나이: 34

# %%
"백승준"
# Out:
# '백승준'

# %%
'123'
# Out:
# '123'

# %%
123
# Out:
# 123

# %%
123 == '123'  # False
# Out:
# False
